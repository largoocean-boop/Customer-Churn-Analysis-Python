# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Success!")
# Out:
# Success!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Success!")
# Out:
# Success!

# %%
import pandas as pd

df = pd.read_csv("customer_churn_dataset-testing-master.csv")

df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64374 entries, 0 to 64373
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         64374 non-null  int64
#  1   Age                64374 non-null  int64
#  2   Gender             64374 non-null  str
#  3   Tenure             64374 non-null  int64
#  4   Usage Frequency    64374 non-null  int64
#  5   Support Calls      64374 non-null  int64
#  6   Payment Delay      64374 non-null  int64
#  7   Subscription Type  64374 non-null  str
#  8   Contract Length    64374 non-null  str
#  9   Total Spend        64374 non-null  int64
#  10  Last Interaction   64374 non-null  int64
#  11  Churn              64374 non-null  int64
# dtypes: int64(9), str(3)
# memory usage: 5.9 MB

# %%
df.shape
# Out:
# (64374, 12)

# %%
df.describe()
# Out:
#          CustomerID           Age        Tenure  Usage Frequency  \
# count  64374.000000  64374.000000  64374.000000     64374.000000
# mean   32187.500000     41.970982     31.994827        15.080234
# std    18583.317451     13.924911     17.098234         8.816470
# min        1.000000     18.000000      1.000000         1.000000
# 25%    16094.250000     30.000000     18.000000         7.000000
# 50%    32187.500000     42.000000     33.000000        15.000000
# 75%    48280.750000     54.000000     47.000000        23.000000
# max    64374.000000     65.000000     60.000000        30.000000
#
#        Support Calls  Payment Delay   Total Spend  Last Interaction  \
# count   64374.000000   64374.000000  64374.000000      64374.000000
# mean        5.400690      17.133952    541.023379         15.498850
# std         3.114005       8.852211    260.874809          8.638436
# min         0.000000       0.000000    100.000000          1.000000
# ...

# %%
churn_rate = df["Churn"].mean() * 100

print(f"Overall Churn Rate: {churn_rate:.2f}%")
# Out:
# Overall Churn Rate: 47.37%

# %%
churn_counts = df["Churn"].value_counts()

plt.figure(figsize=(6,4))
churn_counts.plot(kind="bar")

plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
contract_churn = df.groupby("Contract Length")["Churn"].mean() * 100

print(contract_churn)
# Out:
# Contract Length
# Annual       46.216721
# Monthly      51.608676
# Quarterly    44.048190
# Name: Churn, dtype: float64

# %%
contract_churn.plot(kind="bar")

plt.title("Churn Rate by Contract Length")
plt.xlabel("Contract Length")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
gender_churn = df.groupby("Gender")["Churn"].mean() * 100

print(gender_churn)
# Out:
# Gender
# Female    55.049050
# Male      38.579661
# Name: Churn, dtype: float64

# %%
gender_churn.plot(kind="bar")

plt.title("Churn Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
gender_churn = df.groupby("Gender")["Churn"].mean() * 100

print(gender_churn)
# Out:
# Gender
# Female    55.049050
# Male      38.579661
# Name: Churn, dtype: float64

# %%
gender_churn.plot(kind="bar")

plt.title("Churn Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
support_churn = df.groupby("Support Calls")["Churn"].mean() * 100

support_churn.head(10)
# Out:
# Support Calls
# 0    24.219851
# 1    22.884967
# 2    23.150457
# 3    24.835909
# 4    31.837607
# 5    60.462671
# 6    60.611538
# 7    61.782088
# 8    60.956535
# 9    60.909364
# Name: Churn, dtype: float64

# %%
plt.figure(figsize=(8,5))

support_churn.plot()

plt.title("Churn Rate by Number of Support Calls")
plt.xlabel("Support Calls")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
payment_churn = df.groupby("Payment Delay")["Churn"].mean() * 100

payment_churn.head()
# Out:
# Payment Delay
# 0     9.598494
# 1     9.551657
# 2    11.626388
# 3    10.758263
# 4     9.823678
# Name: Churn, dtype: float64

# %%
plt.figure(figsize=(8,5))

payment_churn.plot()

plt.title("Churn Rate by Payment Delay")
plt.xlabel("Payment Delay")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
support_churn = df.groupby("Support Calls")["Churn"].mean() * 100

plt.figure(figsize=(8,5))
support_churn.plot()

plt.title("Churn Rate by Number of Support Calls")
plt.xlabel("Support Calls")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
payment_churn = df.groupby("Payment Delay")["Churn"].mean() * 100

plt.figure(figsize=(8,5))
payment_churn.plot()

plt.title("Churn Rate by Payment Delay")
plt.xlabel("Payment Delay")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
payment_churn = df.groupby("Payment Delay")["Churn"].mean() * 100

plt.figure(figsize=(8,5))

payment_churn.plot()

plt.title("Churn Rate by Payment Delay")
plt.xlabel("Payment Delay")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
tenure_churn = df.groupby("Tenure")["Churn"].mean() * 100

plt.figure(figsize=(8,5))

tenure_churn.plot()

plt.title("Churn Rate by Customer Tenure")
plt.xlabel("Tenure")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
tenure_churn = df.groupby("Tenure")["Churn"].mean() * 100

plt.figure(figsize=(8,5))

tenure_churn.plot()

plt.title("Churn Rate by Customer Tenure")
plt.xlabel("Tenure")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
spend_churn = df.groupby("Total Spend")["Churn"].mean() * 100

plt.figure(figsize=(10,5))

spend_churn.plot()

plt.title("Churn Rate by Total Spend")
plt.xlabel("Total Spend")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
df["Spend Group"] = pd.qcut(df["Total Spend"], q=4)

spend_group_churn = df.groupby("Spend Group")["Churn"].mean() * 100

print(spend_group_churn)
# Out:
# Spend Group
# (99.999, 313.0]    52.511642
# (313.0, 534.0]     50.300663
# (534.0, 768.0]     43.498288
# (768.0, 1000.0]    43.140671
# Name: Churn, dtype: float64

# %%
spend_group_churn.plot(kind="bar")

plt.title("Churn Rate by Customer Spending Quartile")
plt.xlabel("Spending Group")
plt.ylabel("Churn Rate (%)")

plt.show()

# %%
print("Contract Length Churn Rates")
print(df.groupby("Contract Length")["Churn"].mean() * 100)

print("\nGender Churn Rates")
print(df.groupby("Gender")["Churn"].mean() * 100)
# Out:
# Contract Length Churn Rates
# Contract Length
# Annual       46.216721
# Monthly      51.608676
# Quarterly    44.048190
# Name: Churn, dtype: float64
#
# Gender Churn Rates
# Gender
# Female    55.049050
# Male      38.579661
# Name: Churn, dtype: float64

# %%
corr = df.corr(numeric_only=True)

corr["Churn"].sort_values(ascending=False)
# Out:
# Churn               1.000000
# Payment Delay       0.557386
# CustomerID          0.529832
# Support Calls       0.304631
# Tenure              0.195327
# Age                 0.063457
# Last Interaction   -0.002818
# Total Spend        -0.078867
# Usage Frequency    -0.115098
# Name: Churn, dtype: float64

# %%
# %pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------- ----------------- 4.7/8.3 MB 31.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 27.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ----- ---------------------------------- 5.2/37.3 MB 31.1 MB/s eta 0:00:02
#    ------------- -------------------------- 12.3/37.3 MB 30.3 MB/s eta 0:00:01
#    --------------------- ------------------ 19.7/37.3 MB 32.0 MB/s eta 0:00:01
#    ------------------------------ --------- 28.3/37.3 MB 34.5 MB/s eta 0:00:01
#    -------------------------------------- - 36.2/37.3 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 32.1 MB/s  0:00:01
# ...
#
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("customer_churn_dataset-testing-master.csv")

# %%
from sklearn.model_selection import train_test_split

df_model = pd.get_dummies(
    df,
    columns=["Gender", "Subscription Type", "Contract Length"],
    drop_first=True
)

X = df_model.drop(["CustomerID", "Churn"], axis=1)
y = df_model["Churn"]

print(X.shape)
print(y.shape)
# Out:
# (64374, 12)
# (64374,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (51499, 12)
# (12875, 12)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(X_test)

print(y_pred[:10])
# Out:
# [0 0 1 0 1 0 0 0 1 0]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 83.16%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      6793
#            1       0.82      0.83      0.82      6082
#
#     accuracy                           0.83     12875
#    macro avg       0.83      0.83      0.83     12875
# weighted avg       0.83      0.83      0.83     12875

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[5655 1138]
#  [1030 5052]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

plt.title("Customer Churn Prediction - Confusion Matrix")
plt.show()

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_[0]
})

importance = importance.sort_values(
    by="Coefficient",
    ascending=False
)

print(importance.head(10))
# Out:
#                        Feature  Coefficient
# 10     Contract Length_Monthly     0.332760
# 3                Support Calls     0.329506
# 4                Payment Delay     0.210338
# 1                       Tenure     0.035095
# 0                          Age     0.019216
# 6             Last Interaction    -0.000486
# 5                  Total Spend    -0.001005
# 2              Usage Frequency    -0.059067
# 9   Subscription Type_Standard    -0.078418
# 8    Subscription Type_Premium    -0.083604

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      6793
#            1       0.82      0.83      0.82      6082
#
#     accuracy                           0.83     12875
#    macro avg       0.83      0.83      0.83     12875
# weighted avg       0.83      0.83      0.83     12875

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[5655 1138]
#  [1030 5052]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

plt.title("Customer Churn Prediction - Confusion Matrix")
plt.show()

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_[0]
})

importance = importance.sort_values(
    by="Coefficient",
    ascending=False
)

importance.head(10)
# Out:
#                        Feature  Coefficient
# 10     Contract Length_Monthly     0.332760
# 3                Support Calls     0.329506
# 4                Payment Delay     0.210338
# 1                       Tenure     0.035095
# 0                          Age     0.019216
# 6             Last Interaction    -0.000486
# 5                  Total Spend    -0.001005
# 2              Usage Frequency    -0.059067
# 9   Subscription Type_Standard    -0.078418
# 8    Subscription Type_Premium    -0.083604

# %%
importance.head(10).plot(
    x="Feature",
    y="Coefficient",
    kind="bar"
)

plt.title("Top Features Driving Churn")
plt.ylabel("Coefficient")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      6793
#            1       0.82      0.83      0.82      6082
#
#     accuracy                           0.83     12875
#    macro avg       0.83      0.83      0.83     12875
# weighted avg       0.83      0.83      0.83     12875

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_[0]
})

importance = importance.sort_values(
    by="Coefficient",
    ascending=False
)

print(importance.head(10))
# Out:
#                        Feature  Coefficient
# 10     Contract Length_Monthly     0.332760
# 3                Support Calls     0.329506
# 4                Payment Delay     0.210338
# 1                       Tenure     0.035095
# 0                          Age     0.019216
# 6             Last Interaction    -0.000486
# 5                  Total Spend    -0.001005
# 2              Usage Frequency    -0.059067
# 9   Subscription Type_Standard    -0.078418
# 8    Subscription Type_Premium    -0.083604
